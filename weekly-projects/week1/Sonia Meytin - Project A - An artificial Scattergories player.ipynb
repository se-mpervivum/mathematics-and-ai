# %%
# Homework 1 (due 6/28/2024)

# %%
#List of categories
categories = ["Fruits", "Vegetables", "Animals", "Countries", "Cities", "Famous People", "Colors", "Sports", "Clothing", "Food", "Drinks", "Tools", "Flowers", "Movies", "Books", "Songs", "TV Shows", "Brands", "Transport", "Jobs"]

#Lists of Scattergories answers by letter
scatterA = ["Apple", "Artichoke", "Antelope", "Albania", "Aberdeen", "Abraham Lincoln", "Amber", "Archery", "Anorak", "Achiote sauce", "Assam tea", "Allen wrench", "Anthurium", "Aladdin", "Animal Farm", "Abbey (Mitski)", "Adventures of Black Beauty", "Accurist", "Airplane", "Accupuncturist"]
scatterB = ["Banana", "Bean", "Baboon", "Bulgaria", "Babylon", "Benjamin Franklin", "Beige", "Baseball", "Blouse", "Barbecue", "Baozhong tea", "Bellows", "Bellflower", "Bambi", "Brisingr", "Bug Like an Angel (Mitski)", "Babar", "Burberry", "Bicycle", "Businessman"]
scatterC = ["Cherry", "Carrot", "Crab", "Cameroon", "Cabot", "Calvin Coolidge", "Coral", "Cricket", "Cardigan", "Chipotle aioli", "Chai", "Clamp", "Cherry blossom", "Cabin Fever", "Catching Fire", "Come Along (Cosmo Sheldrake)", "Californication", "Chanel", "Car", "Chef"]
scatterD = ["Date", "Dasheen", "Dog", "Denmark", "D'Iberville", "Daniel Webster", "Dandelion", "Darts", "Dress", "Dolma", "Darjeeling tea", "Drill", "Daffodil", "Dumbo", "Dracula", "Dreams (Japanese Breakfast)", "Dad's Army", "Dolce & Gabbana", "Dinghy", "Doorman"]
scatterE = ["Elderberry", "Eggplant", "Elephant", "Egypt", "Eagan", "Edmund Hillary", "Emerald", "Equestrian", "Earring", "Egg tart", "English breakfast tea", "Edger", "Echinacea", "Emma", "Eragon", "Enemy (Imagine Dragons)", "East New York", "Essie", "Elevator", "Electrician"]
scatterF = ["Fig", "Fennel", "Frog", "Fiji", "Fabens", "Francis Scott Key", "Fuchsia", "Fencing", "Fedora", "Frangipane", "Formosa tea", "Fastener", "Foxglove", "Fantastic Mr. Fox", "Fahrenheit 451", "forever (Charli xcx)", "Fairy Tail", "Fake Bake", "Funicular", "Farmer"]
scatterG = ["Grapefruit", "Garlic", "Giraffe", "Ghana", "Gadsden", "Galileo Galilei", "Green", "Golf", "Gown", "Gumbo", "Genmaicha", "Grinder", "Gladiolus", "Gladiator", "Great Expectations", "Green Light (Lorde)", "Game of Thrones", "Grandel", "Gondola", "Geographer"]
scatterH = ["Honeydew", "Horseradish", "Horse", "Hungary", "Hackensack", "Henry David Thoreau", "Hazel", "Handball", "Hat", "Hash browns", "Hibiscus tea", "Hammer", "Hyacinth", "Honey, I Shrunk the Kids", "Hush, Hush", "Heaven (Mitski)", "Hannah Montana", "Hamam", "Helicopter", "Hairdresser"]
scatterI = ["Imbe", "Iceberg lettuce", "Ibis", "Italy", "Idabel", "Isaac Newton", "Indigo", "Ice hockey", "Infinity scarf", "Ice cream float", "Iced tea", "Ice pick", "Iris", "I, Robot", "It", "I Hope You Feel Terrible (Boy Jr.)", "I Am Weasel", "Icebreaker", "Indoor shuttle", "IT specialist"]
scatterJ = ["Jackfruit", "Jicama", "Jackdaw", "Jamaica", "Jacksonville", "James Joyce", "Jade", "Jousting", "Jacket", "Julienne", "Jasmine tea", "Jackhammer", "Jasmine", "Jaws", "Jane Eyre", "Just Like a Movie (Wallows)", "Jeopardy!", "JanSport", "Jet", "Judge"]
scatterK = ["Kiwi", "Kale", "Kangaroo", "Kenya", "Kahului", "Kelly Holmes", "Khaki", "Kickball", "Kimono", "Kimchi", "Kukicha green tea", "Knife", "Kalmia", "Killers of the Flower Moon", "Kiki's Delivery Service", "Kiss Kiss Bang Bang (Specimen)", "Kids' Court", "Kohler", "Kayak", "Karate instructor"]
scatterL = ["Lemon", "Leek", "Lizard", "Libya", "Lafayette", "Lewis Carroll", "Lime", "Longboarding", "Labcoat", "Lasagna", "Lapsang souchong", "Level", "Lilac", "Love, Actually", "Little Women", "Love Me More (Mitski)", "La Femme Nikita", "Lenovo", "Limousine", "Librarian"]
scatterM = ["Melon", "Mushroom", "Monkey", "Malaysia", "Mableton", "Mark Twain", "Mint", "Martial arts", "Muumuu", "Marzipan", "Mint tea", "Mallet", "Marigold", "Mean Girls", "Mockingjay", "Memories (Conan Gray)", "Mad Men", "Mazda", "Motorcycle", "Miner"]
scatterN = ["Nectarine", "Napa Cabbage", "Nightjar", "Nigeria", "Nantucket", "Neil Armstrong", "Navy", "Netball", "Nightgown", "Noodles", "Nilgiri tea", "Nail", "Nasturtium", "Night of the Living Dead", "N.", "Never Ending Song (Conan Gray)", "Naruto", "Nacon", "Narrowboat", "Nurse"]
scatterO = ["Orange", "Onion", "Orangutan", "Oman", "Oakbrook", "Oprah Winfrey", "Orange", "Orienteering", "Overcoat", "Omelette", "Oolong tea", "Oscillating saw", "Orchid", "Once Upon a Time in America", "Once Upon a Book", "Oh Ana (Mother Mother)", "October Road", "Oakley", "Ocean Liner", "Ophthamologist"]
scatterP = ["Plum", "Parsley", "Pufferfish", "Peru", "Pace", "Pierre de Coubertin", "Purple", "Pickleball", "Pants", "Parmesan", "Pu’erh tea", "Pliers", "Phlox", "Pulp Fiction", "Pride and Prejudice", "Pessimistic (Addison Grace)", "Parks and Recreation", "Paladone", "Paddleboard", "Pediatrician"]
scatterQ = ["Quince", "Quamash", "Quagga", "Qatar", "Quakertown", "Quentin Tarantino", "Quartz", "Qianball", "Quilted vest", "Quiche", "Qi Lan", "Quadrant clamp", "Queen Anne's lace", "Quigley Down Under", "Queen Margot", "Queen of Nothing (The Crane Wives)", "Quantum Leap", "Quiksilver", "Quad bike", "Quality control inspector"]
scatterR = ["Raspberry", "Radish", "Robin", "Romania", "Rockville", "Ryan Gosling", "Red", "Rowing", "Robe", "Rugelach", "Rooibos tea", "Ruler", "Rose", "Rise of the Planet of the Apes", "Ragtime", "Ringtone (Mint Green)", "Rainbow Fish", "Raytheon", "Rowboat", "Reactor operator"]
scatterS = ["Strawberry", "Squash", "Seahorse", "Sudan", "Sachse", "Sally Ride", "Silver", "Sailing", "Scarf", "Spaghetti", "Sencha green tea", "Saw", "Snowdrop", "Sex and the City", "Sabriel", "Sick of The Silence (Mother Mother)", "Samantha Who?", "Saab", "Shuttle", "Sous chef"]
scatterT = ["Tamarind", "Tomato", "Tapir", "Tanzania", "Tacoma", "Taylor Swift", "Teal", "Taekwondo", "Top hat", "Tiramisu", "Tea", "Tack", "Tulip", "Terminator", "Tunnel in the Sky", "Thnks fr th Mmrs (Fall Out Boy)", "TaleSpin", "Toyota", "Train", "Trainer"]
scatterU = ["Ugni", "Ube", "Urial", "Uruguay", "Ukiah", "Usain Bolt", "Umber", "Ultimate frisbee", "Underwear", "Udon", "Ube smoothie", "Utility knife", "Ursinia", "Universal Soldier", "Ulysses", "Uncalled For (Emily James)", "Ugly Americans", "Under Armour", "Unicycle", "Umpire"]
scatterV = ["Voavanga", "Verdolaga", "Viper", "Venezuela", "Vacaville", "Vincent van Gogh", "Vermillion", "Volleyball", "Vest", "Vanilla frosting", "Vervain tea", "Vise", "Violet", "V for Vendetta", "Vampire Weekend", "Venus Fly Trap (MARINA)", "VeggieTales", "Vineyard Vines", "Van", "Veterinarian"]
scatterW = ["Watermelon", "Watercress", "Wallaby", "Wales", "Wabash", "Walter Raleigh", "White", "Water polo", "Watch", "Worcestershire sauce", "White tea", "Wrench", "Water lily", "War of the Worlds", "Winnie the Pooh", "Washing Machine Heart (Mitski)", "Wacky Races", "Wacom", "Wagon", "Web developer"]
scatterX = ["Xigua", "Xilacayota", "Xerus", "There are no countries that start with X", "Xenia", "Xavier Dolan", "Xanthous", "Xare", "X-back swimsuit", "Xacutti", "Xian Luo tea", "X-acto knife", "Xeranthemum", "X-Men", "X: A Novel", "X (Poppy)", "Xena: Warrior Princess", "Xbox", "Xebec", "X-ray technician"]
scatterY = ["Yangmei", "Yam", "Yak", "Yemen", "Yakima", "Yuri Gagarin", "Yellow", "Yotsudama", "Yarmulke", "Yakisoba", "Yellow tea", "Y-splitter", "Yarrow", "Young Frankenstein", "Young Mungo", "yeti (Paris Paloma)", "Young Sheldon", "Yamazaki", "Yacht", "Yoga instructor"]
scatterZ = ["Zalzalak", "Zucchini", "Zebra", "Zimbabwe", "Zanesville", "Zayn Malik", "Zircon", "Zourkhaneh", "Zucchetto", "Zhoug", "Zhu cha tea", "Zipper slider", "Zephyranthes", "Zoolander", "Zorro", "ZITTI E BUONI (Måneskin)", "Zoey 101", "Zara", "Zeppelin", "Zookeeper"]

def get_categories():
    print("Here are the available categories:")
    for i, category in enumerate(categories, 1):
        print(f"{i}. {category}")
    
    selected_categories = []
    while len(selected_categories) < 5:
        try:
            choice = int(input(f"Select category {len(selected_categories) + 1} (1-20): "))
            if 1 <= choice <= 20 and categories[choice - 1] not in selected_categories:
                selected_categories.append(categories[choice - 1])
            else:
                print("Invalid choice or category already selected.")
        except ValueError:
            print("Please enter a number between 1 and 20.")

    return selected_categories

def generate_answers(selected_categories, letter):

    #Make empty lists for the answer options for a given letter, and for the final generated answers
    relevant_letter = []
    generated_answers = []

    #Set the answer options to the right letter based on premade lists
    if letter.upper() == "A":
        relevant_letter = scatterA
    elif letter.upper() == "B":
        relevant_letter = scatterB
    elif letter.upper() == "C":
        relevant_letter = scatterC
    elif letter.upper() == "D":
        relevant_letter = scatterD
    elif letter.upper() == "E":
        relevant_letter = scatterE
    elif letter.upper() == "F":
        relevant_letter = scatterF
    elif letter.upper() == "G":
        relevant_letter = scatterG
    elif letter.upper() == "H":
        relevant_letter = scatterH
    elif letter.upper() == "I":
        relevant_letter = scatterI
    elif letter.upper() == "J":
        relevant_letter = scatterJ
    elif letter.upper() == "K":
        relevant_letter = scatterK
    elif letter.upper() == "L":
        relevant_letter = scatterL
    elif letter.upper() == "M":
        relevant_letter = scatterM
    elif letter.upper() == "N":
        relevant_letter = scatterN
    elif letter.upper() == "O":
        relevant_letter = scatterO
    elif letter.upper() == "P":
        relevant_letter = scatterP
    elif letter.upper() == "Q":
        relevant_letter = scatterQ
    elif letter.upper() == "R":
        relevant_letter = scatterR
    elif letter.upper() == "S":
        relevant_letter = scatterS
    elif letter.upper() == "T":
        relevant_letter = scatterT
    elif letter.upper() == "U":
        relevant_letter = scatterU
    elif letter.upper() == "V":
        relevant_letter = scatterV
    elif letter.upper() == "W":
        relevant_letter = scatterW
    elif letter.upper() == "X":
        relevant_letter = scatterX
    elif letter.upper() == "Y":
        relevant_letter = scatterY
    elif letter.upper() == "Z":
        relevant_letter = scatterZ
    
    #Run through each selected category and append the relevant answer from the answer options to the final generated answers list
    for relevant_category in selected_categories:
        number = categories.index(relevant_category) #Get the index number of the category
        relevant_answer = relevant_letter[number] #Get the corresponding category answer in the relevant letter's list
        entry = str(relevant_category) + ": " + str(relevant_answer) #Format a final answer containing both the category name and answer
        generated_answers.append(entry) #Add the final answer to the list of generated answers

    #Convert generated answers list to a newline separated string
    generated_answers = "\n".join([str(item) for item in generated_answers])
    
    return generated_answers

def scattergories():
    print("Welcome to Scattergories!")
    selected_categories = get_categories()
    letter = input("Enter a letter (A-Z): ").strip().upper()
    
    if letter.isalpha() and len(letter) == 1:
        generated_answers = generate_answers(selected_categories, letter)
        print("\nGenerated Answers:")
        print(generated_answers)
    else:
        print("Invalid letter. Please enter a single letter from A to Z.")
        letter = input("Enter a letter (A-Z): ").strip().upper()

if __name__ == "__main__":
    scattergories()
# Out:
# Welcome to Scattergories!
# Here are the available categories:
# 1. Fruits
# 2. Vegetables
# 3. Animals
# 4. Countries
# 5. Cities
# 6. Famous People
# 7. Colors
# 8. Sports
# 9. Clothing
# 10. Food
# 11. Drinks
# 12. Tools
# 13. Flowers
# 14. Movies
# 15. Books
# 16. Songs
# 17. TV Shows
# 18. Brands
# 19. Transport
# 20. Jobs
# Select category 1 (1-20):  19
# Select category 2 (1-20):  2
# Select category 3 (1-20):  14
# Select category 4 (1-20):  16
# Select category 5 (1-20):  3
# Enter a letter (A-Z):  a
# Generated Answers:
# Transport: Airplane
# Vegetables: Artichoke
# Movies: Aladdin
# Songs: Abbey (Mitski)
# Animals: Antelope
